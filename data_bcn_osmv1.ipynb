# %%
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict

# %%
def count_tags(filename):
    tags ={}
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag not in tags.keys():
            tags[elem.tag] = 1
        else: 
            tags[elem.tag] +=1
            
    return tags

# %%
count_tags ("barcelona_spain.osm")
# Out:
# {'bounds': 1,
#  'member': 45381,
#  'nd': 1449648,
#  'node': 1128840,
#  'osm': 1,
#  'relation': 3348,
#  'tag': 610824,
#  'way': 143370}

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "barcelona_spain.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
count_tags ("sample.osm")
# Out:
# {'member': 4178,
#  'nd': 143025,
#  'node': 112884,
#  'osm': 1,
#  'relation': 335,
#  'tag': 61365,
#  'way': 14337}

# %%
# Find problems
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
def key_type(element, keys):
    
    if element.tag == "tag":
        k = element.attrib['k']
        if lower.search(k):
            keys['lower'] += 1
        elif lower_colon.search(k):
            keys['lower_colon'] += 1
        elif problemchars.search(k):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1

    return keys

# %%
street_type_re = re.compile(r'^^[\w-]+', re.IGNORECASE)
street_types = defaultdict (set)

postcode_re = re.compile(r'^[0][8]', re.IGNORECASE)
postcodes = defaultdict (set)

expected = ["Avinguda", "Carrer", "Carretera","Can", "Cami", "Passeig", "Plaza", "Passatge", "Rambla", 
            "Ronda", "Via", "Travessera", "Torrent", "Baixada"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
    return street_types

def audit_postcode(postcodes, postcode):
    postcodes[postcode].add(postcode)
    return postcodes


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit(osmfile):
    
    for event, elem in ET.iterparse(osmfile, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
                elif is_postcode(tag):
                    audit_postcode(postcodes, tag.attrib['v'])
    
    return postcodes, street_types

# %%
audit ("barcelona_spain.osm")
# Out:
# (defaultdict(set,
#              {'08': {'08'},
#               '08001': {'08001'},
#               '08002': {'08002'},
#               '08003': {'08003'},
#               '08004': {'08004'},
#               '08005': {'08005'},
#               '08006': {'08006'},
#               '08007': {'08007'},
#               '08008': {'08008'},
#               '08009': {'08009'},
#               '08010': {'08010'},
#               '08011': {'08011'},
#               '08012': {'08012'},
#               '08013': {'08013'},
#               '08014': {'08014'},
#               '08015': {'08015'},
#               '08016': {'08016'},
#               '08017': {'08017'},
#               '08018': {'08018'},
#               '08019': {'08019'},
#               '08020': {'08020'},
#               '08021': {'08021'},
#               '08022': {'08022'},
#               '08023': {'08023'},
#               '08024': {'08024'},
#               '08025': {'08025'},
#               '08025 BARCELONE': {'08025 BARCELONE'},
#               '08026': {'08026'},
#               '08027': {'08027'},
#               '08028': {'08028'},
#               '08029': {'08029'},
#               '08030': {'08030'},
#               '08031': {'08031'},
#               '08032': {'08032'},
#               '08033': {'08033'},
#               '08034': {'08034'},
#               '08035': {'08035'},
#               '08036': {'08036'},
#               '08037': {'08037'},
#               '08037 BCN': {'08037 BCN'},
#               '08038': {'08038'},
#               '08039': {'08039'},
#               '08040': {'08040'},
#               '08041': {'08041'},
#               '08042': {'08042'},
#               '08071': {'08071'},
#               '08080': {'08080'},
#               '08094': {'08094'},
#               '08105': {'08105'},
#               '08110': {'08110'},
#               '08130': {'08130'},
#               '08172': {'08172'},
#               '08173': {'08173'},
#               '08174': {'08174'},
#               '08182': {'08182'},
#               '08188': {'08188'},
#               '08190': {'08190'},
#               '08191': {'08191'},
#               '08192': {'08192'},
#               '08193': {'08193'},
#               '08195': {'08195'},
#               '08196': {'08196'},
#               '08197': {'08197'},
#               '08198': {'08198'},
#               '08203': {'08203'},
#               '08204': {'08204'},
#               '08210': {'08210'},
#               '08214': {'08214'},
#               '08231': {'08231'},
#               '08290': {'08290'},
#               '08291': {'08291'},
#               '08320': {'08320'},
#               '08328': {'08328'},
#               '08390': {'08390'},
#               '08391': {'08391'},
#               '08620': {'08620'},
#               '08629': {'08629'},
#               '08630': {'08630'},
#               '08690': {'08690'},
#               '08740': {'08740'},
#               '08750': {'08750'},
#               '08755': {'08755'},
#               '08756': {'08756'},
#               '08757': {'08757'},
#               '08758': {'08758'},
#               '08760': {'08760'},
#               '08780': {'08780'},
#               '08820': {'08820'},
#               '08830': {'08830'},
#               '08840': {'08840'},
#               '08849': {'08849'},
#               '08850': {'08850'},
#               '08860': {'08860'},
#               '08870': {'08870'},
#               '08901': {'08901'},
#               '08902': {'08902'},
#               '08903': {'08903'},
#               '08904': {'08904'},
#               '08905': {'08905'},
#               '08906': {'08906'},
#               '08907': {'08907'},
#               '08908': {'08908'},
#               '08910': {'08910'},
#               '08911': {'08911'},
#               '08912': {'08912'},
#               '08913': {'08913'},
#               '08914': {'08914'},
#               '08915': {'08915'},
#               '08916': {'08916'},
#               '08917': {'08917'},
#               '08918': {'08918'},
#               '08921': {'08921'},
#               '08922': {'08922'},
#               '08923': {'08923'},
#               '08924': {'08924'},
#               '08930': {'08930'},
#               '08940': {'08940'},
#               '08950': {'08950'},
#               '08960': {'08960'},
#               '08970': {'08970'},
#               '08980': {'08980'},
#               '089809': {'089809'},
#               '09870': {'09870'},
#               '28038': {'28038'},
#               '72': {'72'},
#               '80002': {'80002'},
#               '8002': {'8002'},
#               '8007': {'8007'},
#               '8025': {'8025'},
#               'Barcelona': {'Barcelona'}}),
#  defaultdict(set,
#              {u'2': {u'2 Pla\xe7a de la Virreina'},
#               '20': {'20'},
#               '22': {'22'},
#               '31': {'31'},
#               'A-2': {'A-2 KM 8.000'},
#               'ACCESO': {'ACCESO AEROPUERTO DE BARCELONA, LADO AIRE, S/N'},
#               'AGUSTI': {'AGUSTI I MILA, 38'},
#               'ANTONIO': {'ANTONIO GAUDI '},
#               'AUTOPISTA': {'AUTOPISTA AP-7 KM 165.5',
#                'AUTOPISTA AP-7 KM. 144',
#                'AUTOPISTA C- 33 KM 82.5'},
#               'AUTOVIA': {'AUTOVIA CASTELLDEFELS KM 2.7',
#                'AUTOVIA CASTELLDEFELS KM 4.500'},
#               'AV': {'AV.ELECTRICIDAD,ESQ.CHAPLIN C.VALLHONRAT'},
#               'AVDA': {'AVDA COMUNIDAD EUROPEA S/N',
#                'AVDA. BARCELONA, 222 (N-340)',
#                'AVDA. BARCELONA, 28 ESQ.AVD. V. MONTSERRAT   P.I. FONTSANTA',
#                'AVDA. BARCELONA, 41-43'},
#               'AVENIDA': {'AVENIDA AUGUSTA, SN',
#                'AVENIDA BAIX LLOBREGAT, S/N',
#                'AVENIDA BARCELONA S/N',
#                'AVENIDA BOGATELL',
#                'AVENIDA CALDES',
#                u'AVENIDA DE GAV\xc1, ESQ. JOSEP TARRADELLAS, SN',
#                'AVENIDA DE LA GENERALITAT',
#                'AVENIDA DEL LITORAL',
#                'AVENIDA DEL REMOLAR, 37,39',
#                'AVENIDA DINAMARCA ESQ. COMUNIDAD EUROPEA, S/N',
#                'AVENIDA FABREGADA',
#                'AVENIDA JOSEP ANSELM CLAVE',
#                'AVENIDA LLUIS COMPANYS, S/N',
#                'AVENIDA MERIDIANA',
#                'AVENIDA VIA AUGUSTA'},
#               'Abat': {'Abat Oliva'},
#               'Adria': {'Adria Gual'},
#               'Alacant': {'Alacant'},
#               u'Alc': {u'Alc\xe0ntara'},
#               'Aldana': {'Aldana'},
#               'Alfons': {'Alfons XII'},
#               'Almirall': {'Almirall Cervera'},
#               u'Almog': {u'Almog\xe0vers'},
#               u'Andrea': {u'Andrea D\xf2ria'},
#               u'Antiga': {u'Antiga Carretera de Val\xe8ncia'},
#               'Antoni': {'Antoni de Capmany, 72'},
#               u'Arag': {u'Arag\xf3'},
#               'Aribau': {'Aribau'},
#               'Arquitectura': {'Arquitectura'},
#               'Ateneu': {'Ateneu'},
#               'Autopista': {'Autopista C-33 KM 5.2'},
#               'Autovia': {'Autovia de Castelldefels'},
#               'Av': {'Av meridiana',
#                'Av. Barcelona  - BV 2002',
#                'Av. Catalunya',
#                'Av. Diagonal',
#                'Av. Josep Tarradellas i Joan',
#                'Av. Maria Torras',
#                'Av. Mistral',
#                'Av. Mistral, 10',
#                'Av. Remolar',
#                'Av. Roma',
#                'Av. Vilanova',
#                'Av. de Sant Mateu 2',
#                'Av. de la Catedral',
#                'Av. del Litoral'},
#               'Avda': {'Avda. Badalona',
#                'Avda. Burgos',
#                'Avda. Hospital Militar, 231-237',
#                'Avda. Litoral'},
#               u'Avenida': {'Avenida Bogatell',
#                'Avenida Carmen Amaya',
#                'Avenida Diagonal',
#                'Avenida Doctor Bassols',
#                u'Avenida Gaud\xed',
#                'Avenida Icaria',
#                'Avenida Lluis Companys',
#                'Avenida Maria Girona',
#                'Avenida Meridiana',
#                'Avenida Republica Argentina',
#                'Avenida de Madrid',
#                u'Avenida de la Constituci\xf3n'},
#               'Aviador': {'Aviador Franco'},
#               'Avinguida': {'Avinguida de la fama'},
#               'Avnd': {'Avnd.de los Banys'},
#               u'B-500': {u'B-500 Carretera de Badalona a Mollet del Vall\xe8s'},
#               'BOTANICA': {'BOTANICA'},
#               'BP-1417': {"BP-1417 (L'ARRABASSADA) KM 4.9"},
#               'BV': {'BV 2002', 'BV 2003'},
#               'BV-2002': {'BV-2002'},
#               'Bac': {'Bac de Roda'},
#               'Badalona': {'Badalona'},
#               'Balboa': {'Balboa'},
#               'Baldaya': {'Baldaya'},
#               u'Baltasar': {u'Baltasar Graci\xe1n'},
#               'Barcelona': {'Barcelona'},
#               'Barri': {'Barri Bon Punt'},
#               'Beat': {'Beat Almato'},
#               'Bilbao': {'Bilbao'},
#               'Bisbe': {'Bisbe Laguarda'},
#               'Blai': {'Blai'},
#               'Blasco': {'Blasco de Garay'},
#               'Bofarull': {'Bofarull'},
#               'Buenos': {'Buenos Aires'},
#               'C': {u'C Al\xed Bei',
#                'C Barcelona',
#                'C Consell de Cent',
#                u'C Crist\xf3bal de Moura',
#                'C Llacuna',
#                u'C N\xe0pols',
#                u'C Proven\xe7als',
#                u'C Rossell\xf3',
#                u'C. Mare de D\xe8u de Montserrat',
#                'C. Sant Isidre',
#                'C. de Esteve Terradas',
#                'C/ ARTESA DE SEGRE',
#                'C/ Burgos',
#                'C/ CASTANYER',
#                u'C/ CERDE\xd1A, 225-229',
#                u'C/ DE P\xc0DUA',
#                'C/ Esteve Terradas, 1008860 Castelldefels',
#                'C/ F (ZONA FRANCA) km CENTRO COMERCIAL M',
#                u'C/ FRANCOL\xcd',
#                'C/ Germa Juli',
#                'C/ MAGNETISME, 1 (B-150)',
#                u'C/ Occit\xe0nia,',
#                'C/ RIERA MONTEALEGRE, 12 km CENTRO COMERCIAL M',
#                'C/ Sant Casimir',
#                "C/ Torrent de l'Olla",
#                'C/Sant Bru',
#                'C/TORRASSA, 87-95'},
#               'CALLE': {'CALLE AGRICULTURA',
#                'CALLE ARMENTERES',
#                'CALLE BOTANICA, 21/23',
#                'CALLE CALLE Y PUERTO AUTONOMO, S/N',
#                'CALLE CARRETERA DE MATARO',
#                'CALLE CARRETERA REIAL',
#                'CALLE CIENCIES, SN',
#                'CALLE CRAYWINKEL',
#                'CALLE DOCTOR AIGUADER',
#                'CALLE DOMENECH I MONTANER',
#                'CALLE EL PRAT',
#                'CALLE ENERGIA, 73/83',
#                'CALLE GALILEU',
#                'CALLE GRAN VIA',
#                'CALLE GUIPUZCOA, S/N',
#                'CALLE IRADIER, S/N',
#                u'CALLE JOAN G\xdcELL',
#                'CALLE LEGALIDAD',
#                'CALLE LLULL ESQ EDUAR MARISTANY, S/N',
#                'CALLE MAJOR',
#                'CALLE MEXICO, S/N',
#                'CALLE MOZART',
#                'CALLE MURCIA, S/N',
#                'CALLE PABLO IGLESIAS',
#                'CALLE PARAIRES',
#                'CALLE PEDRO IV',
#                'CALLE PEDROIV',
#                'CALLE PORT DE HAIFA, S/N',
#                'CALLE PROGRESO ESQUINA ALBERT EISTEIN, SN',
#                'CALLE PUJADES',
#                'CALLE RAMON Y CAJAL, S/N',
#                'CALLE RENCLUSA',
#                'CALLE SANTA ANNA',
#                'CALLE SANTANDER',
#                'CALLE TARRAGONA, 15-19 ESQ.CALLE BALMES',
#                'CALLE TIRSO DE MOLINA'},
#               'CAN': {'CAN MASACHS'},
#               'CARRETERA': {'CARRETERA AUTOVIA CASTELLDEFELS KM 16.600',
#                'CARRETERA BARCELONA 18-20 KM 7.5',
#                'CARRETERA BARCELONA KM 6.7',
#                'CARRETERA BP-1503 KM 20.270',
#                'CARRETERA BV-2005 KM 4.7',
#                'CARRETERA BV-5001 KM 11.6',
#                'CARRETERA C-17 KM 0.500',
#                'CARRETERA C-17 KM 1.5',
#                'CARRETERA C5502 KM 7.4',
#                'CARRETERA CR BP-1503 KM 18.4',
#                'CARRETERA DE LA SANSON, NUMERO 78 KM. 78',
#                'CARRETERA E-9 KM 14.7',
#                'CARRETERA E-9 KM 14.9',
#                'CARRETERA ESPLUGUES KM. 219',
#                'CARRETERA GARRAF KM. 21',
#                'CARRETERA N-150 BARCELONA-SABADELL KM. 286',
#                'CARRETERA N-150 KM 8.6',
#                'CARRETERA N-152A KM 15.1',
#                'CARRETERA N-2 KM 593.5',
#                'CARRETERA N-340 KM 1234.5',
#                'CARRETERA N-340 KM. 1246',
#                'CARRETERA NACIONAL 340 KM 1249.900',
#                'CARRETERA SANT ADRIA  ROCA KM. 7',
#                'CARRETERA SANTA CREU DE CALAFELL DE KM. 10',
#                'CARRETERA SANTIGA KM 0.430'},
#               'CL': {'CL ALMOGAVARES  159 - 161',
#                'CL F.JUNIP.SERRA ESQU.SANTANDER',
#                'CL FEDERICA MONTSENY 2',
#                'CL INDUSTRIA',
#                'CL LAUREA MIRO',
#                'CL TAJO, 28-34',
#                'CL TARRAGONA, 29-31',
#                'CL VIA FAVENCIA  75 - 121'},
#               'CR': {'CR ALELLA  KM 1',
#                'CR AUTOPISTA AP-7 KM 144.1',
#                'CR C-1413 ,P.K. 9,8',
#                'CR C-1413, 7,7 (C-1413 KM 7.75)',
#                'CR C-245  GARRAF-BARCELONA KM 8.9 (CARRETERA km 179)',
#                'CR N-2, 591,3'},
#               'CRA': {'CRA. MARTORELL 11-19 C.C. ATRIUM-CAPRABO'},
#               'CRTA': {'CRTA. RUBI - ST.CUGAT - C.C. CAPRABO'},
#               'CTRA': {"CTRA de L'Hospitalet",
#                'CTRA. DE MOLINS DE REI KM 12.7'},
#               'Ca': {"Ca l'Alegre de Dalt"},
#               'Calle': {'Calle Afores',
#                'Calle Carders',
#                'Calle Comte Borrell del',
#                "Calle D'en Robador",
#                u'Calle Doctor Ar\xfas',
#                'Calle Flor de Nit (dondiego)',
#                'Calle Guineueta',
#                'Calle Industria de la',
#                'Calle Isard',
#                'Calle Moli Vell del',
#                'Calle Ricard Strauss',
#                'Calle Riereta',
#                'Calle Sant Casimir',
#                'Calle Sant Joan Bosco de',
#                'Calle Sense Nom 002',
#                'Calle Tetuan',
#                'Calle Torre Figueras de la',
#                'Calle Valencia de',
#                'Calle Valencia,',
#                'Calle Vidua de Vives de la',
#                'Calle Vistalegre',
#                'Calle de la Marina'},
#               'Caller': {'Caller de Socrates'},
#               'Calvet': {'Calvet'},
#               u'Cam': {u'Cam\xed Antic Calder\xed',
#                u'Cam\xed Antic de Val\xe8ncia',
#                u'Cam\xed Can Pe\xf1asco',
#                u'Cam\xed Escola Col\xf2nia G\xfcell',
#                u'Cam\xed Vell Sant Ramon',
#                u'Cam\xed Vell de Sarri\xe0',
#                u'Cam\xed a Sant Antoni',
#                u'Cam\xed a la deixalleria',
#                u'Cam\xed de Cal Franc\xe8s',
#                u'Cam\xed de Cal Pelut',
#                u'Cam\xed de Can Casanovas',
#                u'Cam\xed de Can Farr\xe9s',
#                u'Cam\xed de Can Ferrers',
#                u'Cam\xed de Can Mallol a Can Colomer',
#                u'Cam\xed de Can Pongem',
#                u'Cam\xed de Can Ruti',
#                u'Cam\xed de Can Salgado',
#                u'Cam\xed de Can Salgado a Can Ros',
#                u'Cam\xed de Can Via',
#                u'Cam\xed de Ferran Puig',
#                u'Cam\xed de cal Penyasco',
#                u'Cam\xed de la Pava',
#                u'Cam\xed de la Rabassalet',
#                u'Cam\xed de la Ribera',
#                u'Cam\xed de la Torre Melina',
#                u'Cam\xed de les Monges',
#                u'Cam\xed de les Roquetes',
#                u'Cam\xed del Bosquet del Cementiri',
#                u'Cam\xed del Salze'},
#               'Camino': {'Camino Montanyeta N 1',
#                'Camino Montanyeta N 2',
#                'Camino Montanyeta N 3',
#                'Camino Torrefigueras'},
#               u'Camp': {u"Camp d'Aviaci\xf3"},
#               'Campus': {'Campus UAB'},
#               'CarRoc': {'CarRoc Boronat'},
#               'Carders': {'Carders'},
#               'Carles': {'Carles Buigas'},
#               u'Carrar': {u'Carrar de Pere Seraf\xed'},
#               'Carre': {'Carre Ferran', 'Carre de Pau Claris'},
#               'CarrerAlt': {'CarrerAlt'},
#               'Carrerde': {'Carrerde la Magnolia'},
#               u'Carrerl': {u'Carrerl del Per\xfa'},
#               'Carrier': {'Carrier dels Canvis Vels'},
#               'Castelao': {'Castelao'},
#               u'Castell': {u'Castell\xf3'},
#               'Castillejos': {'Castillejos'},
#               'Catalans': {'Catalans'},
#               u'Cicer': {u'Cicer\xf3'},
#               'Clementina': {'Clementina Arderiu'},
#               'Collblanc': {'Collblanc, 14-16'},
#               'Colom': {'Colom street'},
#               'Comandant': {'Comandant Benitez'},
#               u'Comer': {u'Comer\xe7'},
#               'Comte': {'Comte Borrell',
#                "Comte d'Urgell",
#                'Comte de Salvatierra'},
#               'Concili': {'Concili de Trento'},
#               'Consell': {'Consell de Cent'},
#               u'Cop': {u'Cop\xe8rnic'},
#               'Costa': {'Costa i Cuxart'},
#               'Creu': {'Creu dels Molers'},
#               'Cristobal': {'Cristobal de Moura'},
#               'Ctra': {u'Ctra. Bv-2002(Sant Vicen\xe7 dels Horts a Sant Boi)',
#                'Ctra. Del Mig, 36-38 Esq.C/Miguel Romeu, 128-132',
#                'Ctra. NII-a Km. 593.900',
#                u'Ctra. Sant Cugat a Rub\xed',
#                'Ctra. de Corbera (BV-2421)',
#                u'Ctra. de Matar\xf3'},
#               'Diagonal': {'Diagonal'},
#               u'Diputaci': {u'Diputaci\xf3'},
#               'Diputacio': {'Diputacio'},
#               'Diseminados': {'Diseminados Marina'},
#               'Distrito': {'Distrito Ribera'},
#               'Doctor': {'Doctor Aiguader',
#                'Doctor Pi i Molist',
#                'Doctor Trueta'},
#               'Dr': {'Dr. Moragas'},
#               'Drassanes': {'Drassanes'},
#               'Edifici': {'Edifici C - Campus de la UAB'},
#               'Eivissa': {'Eivissa'},
#               'El': {'El Parc del Forum'},
#               'Elkano': {'Elkano'},
#               u'Emp': {u'Emp\xfaries'},
#               'Enric': {'Enric Granados'},
#               'Enrique': {'Enrique Granados'},
#               u'Enten': {u'Enten\xe7a'},
#               u'Escales': {u'Escales Pare Pere Boronat a \xc0ngel Guimer\xe0'},
#               'Escullera': {'Escullera del Poble Nou'},
#               u'Espig': {u'Espig\xf3 de Bac de Roda'},
#               u'Estel': {u'Estel\xed'},
#               'Esteve': {'Esteve Terradas'},
#               'Eucaliptus': {'Eucaliptus'},
#               'Felip': {'Felip I'},
#               u'Ferrer': {u'Ferrer i Gu\xe1rdia'},
#               u'Finl': {u'Finl\xe0ndia'},
#               'Floridablanca': {'Floridablanca'},
#               'Fonthonrada': {'Fonthonrada'},
#               'Fra': {'Fra Juniper Serra'},
#               'Frededic': {'Frededic Puig'},
#               'Frederic': {'Frederic Puig'},
#               'Freneria': {'Freneria'},
#               'GRUNYI': {'GRUNYI 7'},
#               u'Gign': {u'Gign\xe0s'},
#               'Ginebra': {'Ginebra'},
#               'Girona': {'Girona'},
#               'Gomis': {'Gomis'},
#               'Gran': {'Gran Via',
#                'Gran Via Corts Catalanes',
#                'Gran Via de Carles III',
#                'Gran Via de la Corts Catalanes',
#                'Gran Via de les Corts Catalanes',
#                'Gran Via de les Corts Catalanes (lateral mar)',
#                u'Gran de Gr\xe0cia',
#                'Gran de Sant Andreu',
#                'Gran via Cortes Catalanes'},
#               'Guardiola': {'Guardiola i Feliu'},
#               'Hospital': {'Hospital'},
#               u'Hostafrancs': {u'Hostafrancs de Si\xf3'},
#               'Immaculada': {'Immaculada'},
#               'Independencia': {'Independencia'},
#               u'Isidre': {u'Isidre Mart\xed'},
#               'JOSEP': {'JOSEP COMAS 95'},
#               'Jacint': {'Jacint Verdaguer'},
#               u'Jard': {u'Jard\xed T\xf2quio',
#                u'Jard\xed de Margarita Wirsing i Bordas'},
#               u'Jardins': {'Jardins de Blanca Selva i Henry',
#                u'Jardins de Can Cui\xe0s',
#                u'Jardins de Gaiet\xe0 Renom',
#                'Jardins de Joan Altisent',
#                'Jardins de Marcos Redondo',
#                u"Jardins de Maria \xc0ngels Anglada i d'Abadal",
#                u'Jardins de la Penya Regal\xe8ssia',
#                u'Jardins del Doctor Castell\xf3',
#                'Jardins del Doctor Samuel Hahnemann'},
#               'Jaume': {'Jaume Fabra'},
#               'Joan': {'Joan Maragall', 'Joan Miro', u'Joan Mir\xf3'},
#               u'Josep': {u'Josep Vicen\xe7 Foix'},
#               'LUGAR': {'LUGAR AEROPUERTO DEL PRAT JUNTO PARRILLA DE TAXIS, S/N'},
#               'La': {'La Rambla', 'La Ramblas', 'La Selva', 'La ramblas'},
#               u'Lan': {u'Lan\xe7a'},
#               'Lanzarote': {'Lanzarote'},
#               'Lateral': {'Lateral Gran Via de les Corts Catalanes'},
#               'Les': {'Les Rambles'},
#               'Llacuna': {'Llacuna'},
#               u'Llan': {u'Llan\xe7\xe0'},
#               'Llull': {'Llull'},
#               'Lope': {'Lope de Vega'},
#               'Luxemburgo': {'Luxemburgo'},
#               'MOIANES': {'MOIANES'},
#               'MOSSEN': {'MOSSEN JACINTO VERDAGUER, 83-85'},
#               u'Magalh': {u'Magalh\xe3es'},
#               'Mallorca': {'Mallorca'},
#               'Malves': {'Malves'},
#               'Manso': {'Manso'},
#               u'Marcelino': {u'Marcelino Men\xe9ndez y Pelayo'},
#               'Mare': {u'Mare de D\xfa de N\xfaria', 'Mare de deu del Coll'},
#               'Margarit': {'Margarit'},
#               'Maria': {'Maria Fortuny'},
#               u'Mart': {u'Mart\xed i Codolar'},
#               'Mas': {'Mas Blau 2 Business Park, Av. de les Garrigues'},
#               'Masia': {'Masia de Can Via'},
#               'Merkat': {'Merkat de la Boqueria'},
#               'Moll': {'Moll Barcelona',
#                'Moll Pescadors',
#                'Moll Pescadors,',
#                "Moll d'Espanya",
#                'Moll de Barcelona',
#                'Moll de Gregal'},
#               u'Moss': {u'Moss\xe8n Anton Romeu',
#                u'Moss\xe8n Jacint Verdaguer'},
#               'Muntaner': {'Muntaner'},
#               'N-340': {'N-340'},
#               'Nacional': {'Nacional 150 km 1.5'},
#               'Nicaragua': {'Nicaragua'},
#               'Nostra': {"Nostra Senyora de l'Estrada"},
#               'Nou': {'Nou de Zurbano', 'Nou de la Rambla'},
#               'Numancia': {'Numancia'},
#               'Olivera': {'Olivera'},
#               'Olzinelles': {'Olzinelles'},
#               u'P': {u'P\xba de la Zona Franca, 221-239'},
#               'PASEO': {'PASEO CALVELL',
#                'PASEO DOCTOR PI Y MOLIST',
#                'PASEO SANTA COLOMA',
#                'PASEO VALLDAURA'},
#               'PERE': {'PERE IV'},
#               'PLAZA': {'PLAZA MAESTRO CLAVE'},
#               'POLIGONO': {'POLIGONO CAMI DEL MIG',
#                'POLIGONO INDUSTRIAL HERMES'},
#               'PS': {'PS PASSEIG DE COLOMER S/N'},
#               'Paaseig': {'Paaseig Doctor Moragas'},
#               'Pablo': {'Pablo Neruda'},
#               'Padilla': {'Padilla'},
#               'Paisos': {'Paisos Catalans'},
#               'Palau': {'Palau'},
#               'Parc': {'Parc Princep de girona'},
#               'Parlament': {'Parlament'},
#               u'Pas': {u"Pas de l'Encarnaci\xf3", 'Pas de la Marina'},
#               'Pasatge': {'Pasatge Lluisa Vidal'},
#               'Paseo': {'Paseo Barceloneta',
#                'Paseo Garbi',
#                'Paseo Isabel II',
#                'Paseo Maritimo',
#                u'Paseo Portes\xed',
#                'Paseo de la Marina'},
#               u'Passad': {u"Passad\xeds de l'Encarnaci\xf3"},
#               'Pau': {'Pau Casals', 'Pau Claris'},
#               'Pelai': {'Pelai'},
#               u'Pened': {u'Pened\xe8s'},
#               'Pere': {'Pere IV'},
#               u'Pg': {'Pg Castanyers',
#                'Pg Fabra i Puig',
#                u'Pg Gr\xe0cia',
#                u'Pg J Borb\xf3 Comte Barcelona',
#                "Pg Vall d'Hebron 171",
#                'Pg. Manuel Girona 10',
#                u'Pg. de Gr\xe0cia'},
#               'Pi': {'Pi i Margall'},
#               'Pizarro': {'Pizarro'},
#               'Pl': {u'Pl Alfonso Com\xedn',
#                'Pl Catalunya',
#                'Pl Mar',
#                'Pl, Pi Tallat',
#                u'Pl. Constituci\xf3'},
#               u'Pla': {'Pla de Palau',
#                'Pla de la Seu',
#                'Pla del Palau',
#                u'Pla\xe7a Ausias March',
#                u'Pla\xe7a Basses de sant pere',
#                u'Pla\xe7a Benet Barcelona',
#                u'Pla\xe7a Catalunya',
#                u'Pla\xe7a Cervantes',
#                u'Pla\xe7a Comercial',
#                u'Pla\xe7a Conc\xf2rdia',
#                u'Pla\xe7a C\xedvica',
#                u'Pla\xe7a Doctor Letemendi',
#                u'Pla\xe7a Espanya',
#                u'Pla\xe7a Ferran de Sagarra',
#                u'Pla\xe7a Francesc Layret',
#                u'Pla\xe7a Gaiet\xe0 Mestres i Par\xe9s',
#                u'Pla\xe7a Gal\xb7la Placidia',
#                u'Pla\xe7a Guillermo Vida\xf1a i Haro',
#                u'Pla\xe7a Jacint Verdaguer',
#                u'Pla\xe7a Joan G\xfcell',
#                u'Pla\xe7a John Lenon',
#                u'Pla\xe7a Josep Anselm Clav\xe9',
#                u'Pla\xe7a Julio Gonz\xe1lez',
#                u'Pla\xe7a Lloren\xe7 Presas',
#                u'Pla\xe7a Major de Nou Barris',
#                u'Pla\xe7a Margarida Xirgu',
#                u'Pla\xe7a Mediterr\xe0nia',
#                u'Pla\xe7a Moss\xe8n Anton',
#                u'Pla\xe7a Mos\xe9n Jaume Oliveras',
#                u'Pla\xe7a Nova',
#                u'Pla\xe7a Puigmajor',
#                u'Pla\xe7a Ram\xf3n Calsina',
#                u'Pla\xe7a Reial',
#                u'Pla\xe7a Revolucio\xf3 de Setembre 1868, 2, 08012 Barcelona',
#                u'Pla\xe7a Revoluci\xf3 de Setembre 1868, 2, 08012 Barcelona',
#                u'Pla\xe7a Sant Cristofol',
#                u'Pla\xe7a Sant Ramon',
#                u'Pla\xe7a Santa Maria',
#                u'Pla\xe7a Universal',
#                u'Pla\xe7a Urquinaona',
#                u'Pla\xe7a Virreina 5',
#                u"Pla\xe7a d'Alfons el Savi",
#                u"Pla\xe7a d'Antonio L\xf3pez",
#                u"Pla\xe7a d'Avrill\xe9",
#                u"Pla\xe7a d'Eduard Torroja",
#                u"Pla\xe7a d'Eguilaz",
#                u"Pla\xe7a d'Eivissa",
#                u"Pla\xe7a d'Enric Granados",
#                u"Pla\xe7a d'Enric Morera, Sabadell",
#                u"Pla\xe7a d'Ernest Lluch",
#                u"Pla\xe7a d'Europa",
#                u"Pla\xe7a d'Orfila",
#                u"Pla\xe7a d'Osca",
#                u"Pla\xe7a d'Urquinaona",
#                u"Pla\xe7a d'\xc0ngel Rodr\xedguez",
#                u'Pla\xe7a de Alfons al Savi',
#                u'Pla\xe7a de Caba',
#                u'Pla\xe7a de Can Ros\xe9s',
#                u'Pla\xe7a de Casagemes',
#                u'Pla\xe7a de Castella',
#                u'Pla\xe7a de Catalunya',
#                u'Pla\xe7a de Cirera Volt\xe0',
#                u'Pla\xe7a de Comas',
#                u'Pla\xe7a de Ferran Reyes',
#                u'Pla\xe7a de Francesc Maci\xe0',
#                u'Pla\xe7a de Gal\xb7la Plac\xeddia',
#                u'Pla\xe7a de Goya',
#                u'Pla\xe7a de Joan Coromines',
#                u'Pla\xe7a de Joan G\xfcell',
#                u'Pla\xe7a de Joan Llongueras',
#                u'Pla\xe7a de Joan Pelegr\xed',
#                u'Pla\xe7a de Josep M Folch i Torres',
#                u"Pla\xe7a de L'Esgl\xe9sia",
#                u'Pla\xe7a de Leonardo da Vinci',
#                u'Pla\xe7a de Lesseps',
#                u'Pla\xe7a de Llevant',
#                u'Pla\xe7a de Llu\xeds Companys',
#                u'Pla\xe7a de Manuel Corachan',
#                u'Pla\xe7a de Maria Canela',
#                u'Pla\xe7a de Marie Curie',
#                u'Pla\xe7a de Mart\xed Llaurad\xf3',
#                u'Pla\xe7a de Masadas',
#                u'Pla\xe7a de Molina',
#                u'Pla\xe7a de Moss\xe8n Jacint Verdaguer',
#                u'Pla\xe7a de Narc\xeds Oller',
#                u'Pla\xe7a de Pau Casals',
#                u'Pla\xe7a de Pau Vila',
#                u'Pla\xe7a de Pi',
#                u'Pla\xe7a de Prat de la Riba',
#                u'Pla\xe7a de Prim',
#                u'Pla\xe7a de Reus',
#                u'Pla\xe7a de Rovira Trias',
#                u'Pla\xe7a de Salvador Segu\xed',
#                u'Pla\xe7a de San Pere',
#                u'Pla\xe7a de Sant Agust\xed',
#                u'Pla\xe7a de Sant Agust\xed Vell',
#                u'Pla\xe7a de Sant Crist\xf2fol',
#                u'Pla\xe7a de Sant Gregori Taumaturg',
#                u'Pla\xe7a de Sant Iu',
#                u'Pla\xe7a de Sant Jaume',
#                u'Pla\xe7a de Sant Josep Oriol',
#                u'Pla\xe7a de Santa Caterina',
#                u'Pla\xe7a de Santa Magdalena',
#                u'Pla\xe7a de Santa Maria',
#                u'Pla\xe7a de Tetuan',
#                u'Pla\xe7a de Trafalgar',
#                u'Pla\xe7a de Valdivia',
#                u'Pla\xe7a de Vallvidrera',
#                u'Pla\xe7a de Vicen\xe7 Martorell',
#                u'Pla\xe7a de V\xedctor Balaguer',
#                u'Pla\xe7a de Wagner',
#                u'Pla\xe7a de Willy Brandt',
#                u"Pla\xe7a de l' Angeleta Ferrer",
#                u"Pla\xe7a de l'Agricultura",
#                u"Pla\xe7a de l'Ajuntament",
#                u"Pla\xe7a de l'Assemblea de Catalunya",
#                u"Pla\xe7a de l'Esglesia",
#                u"Pla\xe7a de l'Esgl\xe8sia",
#                u"Pla\xe7a de l'Ex\xe8rcit",
#                u'Pla\xe7a de la Barceloneta',
#                u'Pla\xe7a de la Bonanova',
#                u'Pla\xe7a de la Conc\xf2rdia',
#                u'Pla\xe7a de la Constituci\xf3',
#                u'Pla\xe7a de la Font Castellana',
#                u'Pla\xe7a de la Llana',
#                u'Pla\xe7a de la Mare de Deu del Pilar',
#                u'Pla\xe7a de la Mare s/n',
#                u'Pla\xe7a de la Masia',
#                u'Pla\xe7a de la Rep\xfablica',
#                u'Pla\xe7a de la Revoluci\xf3 de Setembre de 1868',
#                u'Pla\xe7a de la Rosa del Vents',
#                u'Pla\xe7a de la Toler\xe0ncia',
#                u'Pla\xe7a de la Universitat',
#                u'Pla\xe7a de la Vila',
#                u'Pla\xe7a de la Vila de Gr\xe0cia',
#                u'Pla\xe7a de la Vila de Madrid',
#                u'Pla\xe7a de les Corts',
#                u'Pla\xe7a de les Gl\xf2ries Catalanes',
#                u'Pla\xe7a de les Palmeres',
#                u'Pla\xe7a de les Vinyes',
#                u"Pla\xe7a de'n Ferran de Sagarra",
#                u'Pla\xe7a del Bonsucc\xe9s',
#                u'Pla\xe7a del Canonge Rod\xf3',
#                u'Pla\xe7a del Carme',
#                u'Pla\xe7a del Centre',
#                u'Pla\xe7a del Doctor Andreu',
#                u'Pla\xe7a del Doctor Barraquer',
#                u'Pla\xe7a del Doctor Ignasi Barraquer',
#                u'Pla\xe7a del Doctor Letamendi',
#                u'Pla\xe7a del Duc de Medinaceli',
#                u'Pla\xe7a del Gall',
#                u'Pla\xe7a del Mar',
#                u'Pla\xe7a del Mercat',
#                u'Pla\xe7a del Moss\xe8n Joan Baranera',
#                u'Pla\xe7a del Nord',
#                u'Pla\xe7a del Pedr\xf3',
#                u'Pla\xe7a del Pi',
#                u'Pla\xe7a del Pi Tallat',
#                u'Pla\xe7a del Poble Roman\xed',
#                u'Pla\xe7a del Poeta Bosc\xe1',
#                u'Pla\xe7a del Regomir',
#                u'Pla\xe7a del Rei',
#                u'Pla\xe7a del Rellotge',
#                u'Pla\xe7a del Sol',
#                u'Pla\xe7a del Sortidor',
#                u'Pla\xe7a del Tr\xe8vol',
#                u'Pla\xe7a del setge de 1714',
#                u"Pla\xe7a dels Jardins d'Alf\xe0bia",
#                u'Pla\xe7a dels Ocellets',
#                u'Pla\xe7a dels Pa\xefsos Catalans',
#                u'Pla\xe7a dels \xc0ngels',
#                u'Pla\xe7a la Vila',
#                u'Pla\xe7eta Montcada',
#                u'Pla\xe7eta del Pi'},
#               u'Placa': {u'Placa Vila de Gr\xe0cia',
#                'Placa de Sant Miquel',
#                'Placa de la Vila de Madrid'},
#               u'Placeta': {u'Placeta Maci\xe0',
#                'Placeta de Joan Brossa',
#                u'Placeta de Mar\xeda Luz Morales',
#                'Placeta de Montcada'},
#               u'Poeta': {'Poeta Cabanyes', u'Poeta Mateu Jan\xe9s'},
#               'Pol': {'Pol. Ind. Zona Franca Sector C, Calle D',
#                u'Pol\xedgono La Granja'},
#               'Pomar': {'Pomar de Baix'},
#               u'Pons': {u'Pons i Subir\xe0'},
#               'Portaferrissa': {'Portaferrissa'},
#               'Prat': {'Prat de la Riba'},
#               u'Proven': {u'Proven\xe7a'},
#               'Provenca': {'Provenca'},
#               u'Provid': {u'Provid\xe8ncia'},
#               u'Pseo': {u'Pseo Mar\xedtimo '},
#               'Pso': {'Pso.Maritimo'},
#               'Ptge': {'Ptge. del Vapor Vell'},
#               u'Puigcerd': {u'Puigcerd\xe0'},
#               'Pujades': {'Pujades'},
#               'Quevedo': {'Quevedo ,6'},
#               'RAMBLA': {'RAMBLA PRIM', 'RAMBLA SANT JOAN'},
#               'RONDA': {'RONDA CERDANYOLA, S/N', 'RONDA SANTA EULALIA'},
#               'Rabassa': {'Rabassa'},
#               'Radas': {'Radas'},
#               u'Ram': {u'Ram\xf3n Turr\xf3', u'Ram\xf3n y Cajal'},
#               'Ramble': {'Ramble de Poblenou'},
#               u'Rambleta': {u'Rambleta Joan Mir\xf3'},
#               'Ramiro': {'Ramiro de Maeztu'},
#               u'Ramon': {'Ramon Llull',
#                u'Ramon Turr\xf2',
#                u'Ramon Turr\xf3',
#                'Ramon y Cajal'},
#               'Ramoneda': {'Ramoneda'},
#               u'Rbla': {u'Rbla. de St. Sebasti\xe0'},
#               'Regent': {'Regent Mendieta'},
#               'Rembla': {'Rembla Catalunya'},
#               'Requesens': {'Requesens'},
#               'Ribot': {'Ribot'},
#               'Riera': {'Riera Blanca',
#                u'Riera Blanca Sarri\xe0',
#                'Riera Canyado',
#                'Riera de Matamoros',
#                'Riera de Vallromanes'},
#               'Riereta': {'Riereta'},
#               'Rocafort': {'Rocafort'},
#               'Roger': {'Roger de', 'Roger de Flor', u'Roger de Ll\xfaria'},
#               'Rosa': {'Rosa Luxemburg'},
#               'Roser': {'Roser'},
#               u'Rossell': {u'Rossell\xf3', u'Rossell\xf3 i Porcel'},
#               u'Ruperto': {u'Ruperto Chap\xed'},
#               'Sagrera': {'Sagrera'},
#               u'Sagu': {u'Sagu\xe9s'},
#               u'Salv': {u'Salv\xe0'},
#               'Salvador': {'Salvador Cardenal'},
#               'Sant': {u'Sant Adri\xe0',
#                'Sant Antoni Maria Claret',
#                'Sant Carles',
#                'Sant Crist',
#                'Sant Domenec',
#                u'Sant Dom\xe8nec del Call',
#                'Sant Erasme',
#                'Sant Joan 39',
#                'Sant Joan Bosco',
#                'Sant Marc',
#                'Sant Oleguer',
#                u'Sant Sebasti\xe0'},
#               u'Santa': {u'Santa Eul\xe0lia', 'Santa Teresa'},
#               'Santiago': {'Santiago Ramon y Cajal', 'Santiago Rusinyol'},
#               'Sardenya': {'Sardenya'},
#               'Secretari': {'Secretari Coloma'},
#               'Segons': {'Segons Jocs Mediterranis'},
#               'Selva': {'Selva de Mar'},
#               u'Sep': {u'Sep\xfalveda 123'},
#               'Serragalliners': {'Serragalliners'},
#               'Sort': {'Sort'},
#               'St': {'St. Joan de La Salle'},
#               'TRAVESIA': {'TRAVESIA INDUSTRIAL'},
#               'TRAVESSIA': {'TRAVESSIA INDUSTRIAL'},
#               'Tamarit': {'Tamarit'},
#               'Tarragona': {'Tarragona'},
#               'Taulat': {'Taulat'},
#               'Teodora': {'Teodora Lamadrid'},
#               'Tibidabo': {'Tibidabo'},
#               'Torent': {"Torent de l'Olla"},
#               'Torras': {'Torras i Bages'},
#               'Travessia': {'Travessia de Sant Antoni'},
#               'Tren': {'Tren'},
#               u'Tur': {u'Tur\xf3 Caritg'},
#               'Tuset': {'Tuset'},
#               'Urgell': {'Urgell'},
#               u'V': {u'V\xeda Favencia', u'V\xeda Laietana'},
#               u'Val': {u'Val\xe8ncia'},
#               'Valencia': {'Valencia'},
#               'Vallirana': {'Vallirana'},
#               'Verge': {'Verge de Montserrat, 2'},
#               'Viaducte': {'Viaducte de Vallcarca'},
#               'Victor': {'Victor Hugo'},
#               'Vidrieria': {'Vidrieria'},
#               'Vila': {'Vila Universitaria, Campus de la UAB',
#                u'Vila i Vil\xe0'},
#               'Viladomat': {'Viladomat'},
#               u'Vilamar': {u'Vilamar\xed'},
#               'Villarroel': {'Villarroel'},
#               'Wellinton': {'Wellinton'},
#               'Xucla': {'Xucla'},
#               'avinguda': {'avinguda Comte Ramon Berenguer',
#                "avinguda d'Alfons XIII",
#                "avinguda d'Almeria",
#                u"avinguda d'Am\xe8rica",
#                u"avinguda d'\xc0frica",
#                'avinguda de Pius XII',
#                'avinguda de Sant Salvador',
#                'avinguda de Vallcarca',
#                'avinguda del Doctor Bassols',
#                'avinguda del Maresme',
#                u'avinguda del Marqu\xe8s de Sant Mori',
#                'avinguda del cardenal Vidal i Barraquer'},
#               'c': {'c. Beethoven',
#                'c. Mestre Nicolau',
#                'c/ Industria',
#                u'c/ Salvador Segu\xed',
#                'c/ Santa Teresa, 40',
#                "c/ Torrent de l'Olla",
#                'c/ tarragona'},
#               u'calle': {u'calle Sic\xedlia', 'calle Verdi', 'calle Vilamari'},
#               u'cam': {u'cam\xed Mol\xed de Les Planes'},
#               u'cami': {u'cami Mol\xed de Les Planes'},
#               u'carrer': {'carrer Ample',
#                u'carrer Apel\xb7les Mestres',
#                'carrer Bosc',
#                'carrer Can Masachs',
#                'carrer Carles Ribas',
#                "carrer Comte d'Urgell",
#                u'carrer Diputaci\xf3',
#                u'carrer Esgl\xe8sia',
#                'carrer Guadia',
#                'carrer Guadiana',
#                'carrer Irlanda',
#                'carrer LLobregat',
#                u'carrer Llan\xe7a',
#                'carrer Major',
#                u'carrer Mir\xf3',
#                u'carrer Montpedr\xf3s',
#                'carrer Pablo Picasso',
#                'carrer Pla de Matabous',
#                'carrer Pou de Sant Pere',
#                u'carrer Proven\xe7a',
#                "carrer Riera de l'Escorxador",
#                u'carrer Torroella de Montgr\xed',
#                'carrer Tuset',
#                'carrer Virgili',
#                'carrer carters 35, 08003 Barcelona ',
#                u"carrer d'Andr\xe9s Segovia",
#                "carrer d'Aribau",
#                u"carrer d'Arn\xfas",
#                "carrer d'Echegaray",
#                "carrer d'Europa",
#                "carrer d'Oceania",
#                u"carrer d'\xc0sia",
#                'carrer de Bellavista',
#                u'carrer de Berl\xedn',
#                'carrer de Don Pelayo',
#                'carrer de Floridablanca',
#                'carrer de Goya',
#                'carrer de Gravina',
#                'carrer de Guasch',
#                'carrer de Jerez de la Frontera',
#                'carrer de Juan Valera',
#                u'carrer de J\xfapiter',
#                'carrer de Lepant',
#                u'carrer de Lle\xf3 Fontova',
#                'carrer de Londres',
#                u'carrer de N\xe0pols',
#                u'carrer de Par\xeds',
#                'carrer de Pau Piferrer',
#                'carrer de Pi i Gibert',
#                'carrer de Ponent',
#                u'carrer de P\xe9rez Gald\xf3s',
#                'carrer de Quevedo',
#                'carrer de Ramiro de Maeztu',
#                'carrer de Ricard Strauss',
#                'carrer de Rius i Taulet',
#                'carrer de Rodrigo Caro',
#                'carrer de Rosa Sensat',
#                u"carrer de Salvador Segu\xed 'Noi del Sucre'",
#                'carrer de Sant Antoni Maria Claret',
#                'carrer de Sants',
#                'carrer de Saragossa',
#                u'carrer de S\xedrius',
#                'carrer de Venero',
#                'carrer de Venus',
#                'carrer de Verdi',
#                "carrer de l'Energia",
#                "carrer de l'Estiu",
#                u'carrer de la Mare de D\xe9u de Lorda',
#                u'carrer de la Mare de D\xe9u de Pompeia',
#                'carrer de la Muntanya',
#                'carrer de la Pau',
#                u'carrer de la S\xe8quia',
#                'carrer de la maquinista',
#                'carrer de la marina',
#                'carrer de les Monges',
#                'carrer de sant Frederic',
#                'carrer del Brasil',
#                'carrer del Comte de Salvatierra',
#                'carrer del Montseny',
#                'carrer del Planeta Mart',
#                u'carrer dels Almog\xe0vers',
#                u'carrer d\xb4Anselm Clav\xe9',
#                u'carrer \xc0ngel Guimer\xe0'},
#               u'carretera': {u'carretera antiga de Val\xe8ncia',
#                'carretera de Santa Coloma',
#                'carretera de la Vila'},
#               'casanova': {'casanova'},
#               u'del': {u'del Rossell\xf3'},
#               'girona': {'girona'},
#               'jardins': {'jardins de la penya regalessia'},
#               'l': {"l'Argenteria"},
#               'la': {'la Rambla'},
#               'marina': {'marina'},
#               'notariat': {'notariat'},
#               u'palam': {u'palam\xf3s'},
#               'parc': {'parc de la ciutadella'},
#               'passatge': {'passatge de Marconi',
#                'passatge de la blada',
#                'passatge dels Encants'},
#               'passeig': {"passeig d'Horta", 'passeig de la Salut'},
#               'pau': {'pau claris'},
#               'picasso': {'picasso'},
#               'pl': {'pl. Palmeres'},
#               u'pla': {u"pla\xe7a Coll de la Creu d'en Blau",
#                u'pla\xe7a Comercial',
#                u'pla\xe7a de Trafalgar',
#                u"pla\xe7a de l'Assemblea de Catalunya",
#                u"pla\xe7a de l'\xc0ngel",
#                u'pla\xe7a de la Farga'},
#               'placa': {'placa del pedro'},
#               u'rambla': {'rambla de la Solidaritat',
#                u'rambla del moss\xe8n jacint verdaguer'},
#               'rbla': {'rbla. Onze de Setembre'},
#               u'ronda': {u'ronda de sant Antoni de Llefi\xe0'},
#               'san': {'san clement'},
#               'santa': {'santa caterina'}}))

# %%
mapping = { "AVDA": "Avinguda",
            "AVENIDA": "Avinguda",
            "Av" : "Avinguda",
            "avinguda": "Avinguda",
            "Avenida" : "Avinguda",
            "C" : "Carrer",
            "c" : "Carrer",
            "Ca": "Carrer",
            "CALLE" : "Carrer",
            "calle": "Carrer",
            "CL" : "Carrer",
            "carrer" : "Carrer",
            "CARRETERA" : "Carretera",
            "carretera" : "Carretera",
            "CR" : "Carretera",
            "CRA" : "Carretera",
            "Pl" : "Plaza",
            "Pla" : "Plaza",
            "pla" : "Plaza",
            "Placa" : "Plaza",
            "Placeta" : "Plaza", 
            "passeig" : "Passeig",
            "Pg" : "Passeig",
            "Paseo" : "Passeig",
            "ronda" : "Ronda",
            "rambla" : "Rambla",
            "RAMBLA" : "Rambla"
            
            }
def update_name(name, mapping):

    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            if street_type in mapping.keys():
                name = re.sub(street_type_re, mapping[street_type], name)

    return name

#Postcode in Barcelona should start with '08' and have 3 more digits. For ex: 08012
def update_postcode(postcode):
    expected = re.match (r'^[0][8]', postcode)
    if expected is None:
        clean_postcode = 'NA'
    else:
         # new regular expression pattern
        search = re.match(r'^\d*(\d{5}).*', postcode)
         # select the group that is captured
        clean_postcode = search.group(1)
    
    return clean_postcode

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema


OSM_PATH = "barcelona_spain.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

SCHEMA = schema.schema

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')



# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

def load_new_tag(element, secondary, default_tag_type):
    """
    Load a new tag dict to go into the list of dicts for way_tags, node_tags
    """
    new = {}
    new['id'] = element.attrib['id']
    if ":" not in secondary.attrib['k']:
        new['key'] = secondary.attrib['k']
        new['type'] = default_tag_type
    else:
        post_colon = secondary.attrib['k'].index(":") + 1
        new['key'] = secondary.attrib['k'][post_colon:]
        new['type'] = secondary.attrib['k'][:post_colon - 1]
        new['value'] = secondary.attrib['v']
    
    print secondary.attrib['v']
    
    return new

# %%
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []
                
        
    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]

        for node_tag in element:
            node_tags = {}
            if LOWER_COLON.match(node_tag.attrib['k']):
                node_tags['type'] = node_tag.attrib['k'].split(':',1)[0]
                node_tags['key'] = node_tag.attrib['k'].split(':',1)[1]
                node_tags['value'] = node_tag.attrib['v']
                node_tags['id'] = element.attrib['id']
                if node_tag.attrib['k'] == 'addr:street':
                    node_tags['value'] = update_name(node_tag.attrib['v'], mapping)
                if node_tag.attrib['k'] == 'addr:postcode':
                        node_tags["value"] = update_postcode(node_tag.attrib['v'])
                else:
                    node_tags['value'] = node_tag.attrib['v']
                tags.append(node_tags)
                
            elif PROBLEMCHARS.match(node_tag.attrib['k']):
                continue
            else:
                node_tags['type'] = 'regular'
                node_tags['id'] = element.attrib['id']
                node_tags['key'] = node_tag.attrib['k'] 
                node_tags['value'] = node_tag.attrib['v']
                tags.append(node_tags)
                
                
        
        return {'node': node_attribs, 'node_tags': tags}


    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]

        position = 0        
        for child in element:
            way_node = {}
            way_tag = {}

            if  child.tag == 'tag':
                if LOWER_COLON.match(child.attrib['k']):
                    way_tag['id'] = element.attrib['id']
                    way_tag['type'] = child.attrib['k'].split(':',1)[0]
                    way_tag['key'] = child.attrib['k'].split(':',1)[1]
                    way_tag['value'] = child.attrib['v']
                    if child.attrib['k'] == 'addr:street':
                        
                        way_tag['value'] = update_name(child.attrib['v'], mapping)
                        print way_tag['value']
                        
                    if child.attrib['k'] == 'addr:postcode':
                        # clean the 'v' attribute (i.e. the value)
                        way_tag["value"] = update_postcode(child.attrib["v"])
                        print way_tag['value']
                    else:
                        way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                   
                elif PROBLEMCHARS.match(child.attrib['k']):
                       continue

                else:
                        way_tag['type'] = 'regular'
                        way_tag['id'] = element.attrib['id']
                        way_tag['key'] = child.attrib['k']
                        way_tag['value'] = child.attrib['v']
                        tags.append(way_tag)

            elif  child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = position
                position += 1
                way_nodes.append(way_node)
                
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
        codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %%
process_map(OSM_PATH, validate=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-1b98a10131f8> in <module>()
# ----> 1 process_map(OSM_PATH, validate=True)
#
# <ipython-input-28-3a222f710571> in process_map(file_in, validate)
#      19
#      20         for element in get_element(file_in, tags=('node', 'way')):
# ---> 21             el = shape_element(element)
#      22             if el:
#      23                 if validate is True:
#
# <ipython-input-26-928891ca7e42> in shape_element(element, node_attr_fields, way_attr_fields, problem_chars, default_tag_type)
#      24                     node_tags['value'] = update_name(node_tag.attrib['v'], mapping)
#      25                 if node_tag.attrib['k'] == 'addr:postcode':
# ---> 26                         node_tags["value"] = update_postcode(node_tag.attrib['v'])
#      27                 else:
#      28                     node_tags['value'] = node_tag.attrib['v']
#
# <ipython-input-9-927e6cc868db> in update_postcode(postcode)
#      47         search = re.match(r'^\d*(\d{5}).*', postcode)
#      48          # select the group that is captured
# ---> 49         clean_postcode = search.group(1)
#      50
#      51     return clean_postcode
#
# AttributeError: 'NoneType' object has no attribute 'group'
